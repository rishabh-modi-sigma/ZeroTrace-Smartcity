# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(
    "C:/zeroTracecodeCraftHackthon/ZeroTrace-Smartcity/uav_carbonnn_emission_dataset.csv"
)

# %%
df.head()
# Out:
#              timestamp   latitude   longitude  altitude_m  CO2_ppm  PM2.5  \
# 0  2023-11-08 20:38:57  37.761140 -122.437077      140.63   439.48  44.21
# 1  2022-10-28 15:14:46  37.779635 -122.424102      148.83   388.36  48.61
# 2  2021-05-02 19:27:46  37.782231 -122.415000      138.32   390.34  21.09
# 3  2021-04-14 15:14:07  37.777718 -122.418567      147.28   391.17  40.68
# 4  2024-01-25 06:08:23  37.770695 -122.427660       80.99   415.91  24.12
#
#    NOx_ppb  SO2_ppb  O3_ppb  temperature_C  humidity_%  wind_speed_mps  \
# 0    16.24     9.63   40.37          24.08       63.86            4.60
# 1    19.16     6.42   64.13          18.27       86.82            5.85
# 2    24.53     5.89   31.22          29.35       36.72            8.50
# 3    25.27    15.02   55.71          37.31       68.39            3.12
# 4    23.81    11.91   47.12          36.30       81.75            4.77
#
#    rainfall_mm emission_level
# 0         0.87           High
# 1         1.16         Medium
# ...

# %%
df = pd.read_csv(
    "C:/zeroTracecodeCraftHackthon/ZeroTrace-Smartcity/uav_carbonnn_emission_dataset.csv"
)

# %%
df = pd.read_csv(
    "C:/zeroTracecodeCraftHackthon/ZeroTrace-Smartcity/uav_carbonnn_emission_dataset.csv"
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       1000 non-null   object
#  1   latitude        1000 non-null   float64
#  2   longitude       1000 non-null   float64
#  3   altitude_m      1000 non-null   float64
#  4   CO2_ppm         1000 non-null   float64
#  5   PM2.5           1000 non-null   float64
#  6   NOx_ppb         1000 non-null   float64
#  7   SO2_ppb         1000 non-null   float64
#  8   O3_ppb          1000 non-null   float64
#  9   temperature_C   1000 non-null   float64
#  10  humidity_%      1000 non-null   float64
#  11  wind_speed_mps  1000 non-null   float64
#  12  rainfall_mm     1000 non-null   float64
#  13  emission_level  1000 non-null   object
# dtypes: float64(12), object(2)
# memory usage: 109.5+ KB

# %%
df.isnull().sum()
# Out:
# timestamp         0
# latitude          0
# longitude         0
# altitude_m        0
# CO2_ppm           0
# PM2.5             0
# NOx_ppb           0
# SO2_ppb           0
# O3_ppb            0
# temperature_C     0
# humidity_%        0
# wind_speed_mps    0
# rainfall_mm       0
# emission_level    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import warnings
warnings.filterwarnings("ignore")
sns.set(style="whitegrid")

# %%
df["emission_level"].unique()
# Out:
# array(['High', 'Medium', 'Low'], dtype=object)

# %%
# Churn distribution this plot shows the proportion of customers who churned and those who did not churn.

df["Churn"].value_counts().plot(kind="pie",autopct="%1.1f%%")
plt.title("Customer Churn Distribution")
plt.ylabel("")
plt.show()

# %%
# Emission level distribution
df["emission_level"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%"
)

plt.title("Emission Level Distribution")
plt.ylabel("")
plt.show()

# %%
sns.countplot(data=df, x="emission_level",hue="emission_level")
plt.title("Emission Level Distribution")
plt.show()

# %%
sns.histplot(
    data=df,
    x="CO2_ppm",
    hue="emission_level",
    kde=True
)

plt.title("CO2 Distribution by Emission Level")
plt.xlabel("CO2 (ppm)")
plt.ylabel("Number of Records")
plt.show()

# %%
# Correlation Analysis

df_corr = df.copy()

corr_matrix = df_corr[
    [
        "latitude",
        "longitude",
        "altitude_m",
        "CO2_ppm",
        "PM2.5",
        "NOx_ppb",
        "SO2_ppb",
        "O3_ppb",
        "temperature_C",
        "humidity_%",
        "wind_speed_mps",
        "rainfall_mm",
        "Total_Pollution",
        "Temp_Humidity",
        "Pollution_Wind_Ratio"
    ]
].corr()

plt.figure(figsize=(12, 8))

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Smart City Pollution Correlation Heatmap")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       1000 non-null   object
#  1   latitude        1000 non-null   float64
#  2   longitude       1000 non-null   float64
#  3   altitude_m      1000 non-null   float64
#  4   CO2_ppm         1000 non-null   float64
#  5   PM2.5           1000 non-null   float64
#  6   NOx_ppb         1000 non-null   float64
#  7   SO2_ppb         1000 non-null   float64
#  8   O3_ppb          1000 non-null   float64
#  9   temperature_C   1000 non-null   float64
#  10  humidity_%      1000 non-null   float64
#  11  wind_speed_mps  1000 non-null   float64
#  12  rainfall_mm     1000 non-null   float64
#  13  emission_level  1000 non-null   object
# dtypes: float64(12), object(2)
# memory usage: 109.5+ KB

# %%
# LabelEncoder 

from sklearn.preprocessing import LabelEncoder 

le = LabelEncoder()

df["emission_level"] = le.fit_transform(df["emission_level"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       1000 non-null   object
#  1   latitude        1000 non-null   float64
#  2   longitude       1000 non-null   float64
#  3   altitude_m      1000 non-null   float64
#  4   CO2_ppm         1000 non-null   float64
#  5   PM2.5           1000 non-null   float64
#  6   NOx_ppb         1000 non-null   float64
#  7   SO2_ppb         1000 non-null   float64
#  8   O3_ppb          1000 non-null   float64
#  9   temperature_C   1000 non-null   float64
#  10  humidity_%      1000 non-null   float64
#  11  wind_speed_mps  1000 non-null   float64
#  12  rainfall_mm     1000 non-null   float64
#  13  emission_level  1000 non-null   int64
# dtypes: float64(12), int64(1), object(1)
# memory usage: 109.5+ KB

# %%
df=df.drop(columns="timestamp",axis=1)

# %%
df.head()
# Out:
#     latitude   longitude  altitude_m  CO2_ppm  PM2.5  NOx_ppb  SO2_ppb  \
# 0  37.761140 -122.437077      140.63   439.48  44.21    16.24     9.63
# 1  37.779635 -122.424102      148.83   388.36  48.61    19.16     6.42
# 2  37.782231 -122.415000      138.32   390.34  21.09    24.53     5.89
# 3  37.777718 -122.418567      147.28   391.17  40.68    25.27    15.02
# 4  37.770695 -122.427660       80.99   415.91  24.12    23.81    11.91
#
#    O3_ppb  temperature_C  humidity_%  wind_speed_mps  rainfall_mm  \
# 0   40.37          24.08       63.86            4.60         0.87
# 1   64.13          18.27       86.82            5.85         1.16
# 2   31.22          29.35       36.72            8.50         1.35
# 3   55.71          37.31       68.39            3.12         0.89
# 4   47.12          36.30       81.75            4.77         0.29
#
#    emission_level
# 0               0
# 1               2
# 2               2
# 3               2
# 4               2

# %%
# Feature Engineering
df["Total_Pollution"] = (
    df["CO2_ppm"] +
    df["PM2.5"] +
    df["NOx_ppb"] +
    df["SO2_ppb"] +
    df["O3_ppb"]
)

df["Temp_Humidity"] = (
    df["temperature_C"] * df["humidity_%"]
)

df["Pollution_Wind_Ratio"] = (
    df["PM2.5"] / (df["wind_speed_mps"] + 1)
)

# %%
# Train_Test_split

from sklearn.model_selection import train_test_split

x = df.drop("emission_level", axis = 1)
y = df["emission_level"]

x_train, x_test , y_train , y_test = train_test_split(
    x , y , test_size = 0.2 , random_state = 42 , stratify=y
)

# %%
from sklearn.preprocessing import StandardScaler

numerical_cols = [
    "latitude",
    "longitude",
    "altitude_m",
    "CO2_ppm",
    "PM2.5",
    "NOx_ppb",
    "SO2_ppb",
    "O3_ppb",
    "temperature_C",
    "humidity_%",
    "wind_speed_mps",
    "rainfall_mm",
    "Total_Pollution",
    "Temp_Humidity",
    "Pollution_Wind_Ratio"
]

scaler = StandardScaler()

x_train_scaled = x_train.copy()
x_test_scaled = x_test.copy()

x_train_scaled[numerical_cols] = scaler.fit_transform(
    x_train[numerical_cols]
)

x_test_scaled[numerical_cols] = scaler.transform(
    x_test[numerical_cols]
)

# %%
df.columns
# Out:
# Index(['latitude', 'longitude', 'altitude_m', 'CO2_ppm', 'PM2.5', 'NOx_ppb',
#        'SO2_ppb', 'O3_ppb', 'temperature_C', 'humidity_%', 'wind_speed_mps',
#        'rainfall_mm', 'emission_level', 'Total_Pollution', 'Temp_Humidity',
#        'Pollution_Wind_Ratio'],
#       dtype='object')

# %%
x_train_scaled.head()
# Out:
#      latitude  longitude  altitude_m   CO2_ppm     PM2.5   NOx_ppb   SO2_ppb  \
# 213 -0.169883  -0.083231    0.850561 -0.530331 -0.064438 -1.151544  1.936104
# 897  0.438980   0.622633    1.108308 -0.838348 -1.107755  2.464973 -1.468430
# 575  0.004043   1.189940    0.487047 -0.436072  1.259184 -1.114515  0.561392
# 68  -0.612317   0.496092    1.466688 -0.393873  0.166071  1.107236 -1.084868
# 595 -0.715334  -0.495179   -0.133187  0.757345 -1.536647 -0.507237 -1.132389
#
#        O3_ppb  temperature_C  humidity_%  wind_speed_mps  rainfall_mm  \
# 213 -1.301278       1.698782    0.925652       -0.341967     1.060358
# 897  1.004626      -1.092414    0.396071       -0.917827    -1.533578
# 575  0.264774       1.158991    0.503120       -0.541303     0.898237
# 68   0.203938      -0.533833    0.411183       -1.578588     1.210899
# 595 -0.825379       0.101616    0.362696       -0.024506    -0.398731
#
#      Total_Pollution  Temp_Humidity  Pollution_Wind_Ratio
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report
)

log_model = LogisticRegression(
    random_state=42,
    max_iter=1000
)

log_model.fit(x_train_scaled, y_train)

y_pred_log = log_model.predict(x_test_scaled)

print("Logistic Regression Results")

print("Accuracy:", accuracy_score(y_test, y_pred_log))
print("Precision:", precision_score(y_test, y_pred_log, average="weighted"))
print("Recall:", recall_score(y_test, y_pred_log, average="weighted"))
print("F1 Score:", f1_score(y_test, y_pred_log, average="weighted"))

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred_log))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_log))
# Out:
# Logistic Regression Results
# Accuracy: 0.895
# Precision: 0.8936548387096775
# Recall: 0.895
# F1 Score: 0.8918475452196382
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.72      0.80        25
#            1       0.84      0.72      0.78        29
#            2       0.90      0.96      0.93       146
#
#     accuracy                           0.90       200
#    macro avg       0.88      0.80      0.84       200
# weighted avg       0.89      0.90      0.89       200
#
# Confusion Matrix:
# [[ 18   0   7]
#  [  0  21   8]
#  [  2   4 140]]

# %%
# Advance Model- Random Forest

from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=200, random_state=42,class_weight="balanced")
rf_model.fit(x_train_scaled, y_train)

y_pred_rf = rf_model.predict(x_test_scaled)

print("Accuracy:", accuracy_score(y_test, y_pred_log))
print("Precision:", precision_score(y_test, y_pred_log, average="weighted"))
print("Recall:", recall_score(y_test, y_pred_log, average="weighted"))
print("F1 Score:", f1_score(y_test, y_pred_log, average="weighted"))

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred_log))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_log))
# Out:
# Accuracy: 0.895
# Precision: 0.8936548387096775
# Recall: 0.895
# F1 Score: 0.8918475452196382
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.72      0.80        25
#            1       0.84      0.72      0.78        29
#            2       0.90      0.96      0.93       146
#
#     accuracy                           0.90       200
#    macro avg       0.88      0.80      0.84       200
# weighted avg       0.89      0.90      0.89       200
#
# Confusion Matrix:
# [[ 18   0   7]
#  [  0  21   8]
#  [  2   4 140]]

# %%
feature_importance = pd.Series(rf_model.feature_importances_, index=x_train.columns).sort_values(ascending=False)
feature_importance
# Out:
# CO2_ppm                 0.439908
# Total_Pollution         0.240603
# PM2.5                   0.108531
# Pollution_Wind_Ratio    0.026744
# NOx_ppb                 0.021836
# O3_ppb                  0.020071
# wind_speed_mps          0.018644
# SO2_ppb                 0.017931
# altitude_m              0.017158
# Temp_Humidity           0.016092
# rainfall_mm             0.015837
# humidity_%              0.015002
# temperature_C           0.014397
# longitude               0.013758
# latitude                0.013488
# dtype: float64

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(rf_model, x_train_scaled, y_train, cv=5, scoring='f1')
print("CV F1 scores:", cv_scores)
print("Mean:", cv_scores.mean())
# Out:
# CV F1 scores: [nan nan nan nan nan]
# Mean: nan

# %%
# !pip install xgboost

# %%
# Advanced Model: XGBoost

from xgboost import XGBClassifier

xgb_model = XGBClassifier(random_state=42, eval_metric="logloss")
xgb_model.fit(x_train_scaled, y_train)

y_pred_xgb = xgb_model.predict(x_test_scaled)

print("Accuracy:", accuracy_score(y_test, y_pred_log))
print("Precision:", precision_score(y_test, y_pred_log, average="weighted"))
print("Recall:", recall_score(y_test, y_pred_log, average="weighted"))
print("F1 Score:", f1_score(y_test, y_pred_log, average="weighted"))

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred_log))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_log))
# Out:
# Accuracy: 0.895
# Precision: 0.8936548387096775
# Recall: 0.895
# F1 Score: 0.8918475452196382
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.72      0.80        25
#            1       0.84      0.72      0.78        29
#            2       0.90      0.96      0.93       146
#
#     accuracy                           0.90       200
#    macro avg       0.88      0.80      0.84       200
# weighted avg       0.89      0.90      0.89       200
#
# Confusion Matrix:
# [[ 18   0   7]
#  [  0  21   8]
#  [  2   4 140]]

# %%
cm_xgb = confusion_matrix(y_test, y_pred_xgb)

sns.heatmap(
    cm_xgb,
    annot=True,
    fmt="d",
    cmap="Purples",
    xticklabels=le.classes_,
    yticklabels=le.classes_
)

plt.title("Confusion Matrix - XGBoost")
plt.xlabel("Predicted Emission Level")
plt.ylabel("Actual Emission Level")
plt.show()

# %%
# Feature Importance - Random Forest

feature_importance = pd.Series(
    rf_model.feature_importances_,
    index=x_train.columns
).sort_values(ascending=False)

plt.figure(figsize=(10, 7))

sns.barplot(
    x=feature_importance.values,
    y=feature_importance.index
)

plt.title("Feature Importance - Random Forest")
plt.xlabel("Importance")
plt.ylabel("Features")
plt.show()

# %%
# Model Explainability with SHAP

# !pip install shap

# %%
import shap

explainer = shap.TreeExplainer(xgb_model)
shap_values = explainer.shap_values(x_test_scaled)
shap_values = explainer.shap_values(x_test_scaled)

# %%
# Global Feature Impact — SHAP Summary Plot

shap.summary_plot(
    shap_values,
    x_test_scaled
)

# %%
import shap
import numpy as np

# Create SHAP explainer
explainer = shap.TreeExplainer(xgb_model)

# Calculate SHAP values
shap_values = explainer.shap_values(x_test_scaled)

# Explain first test sample
idx = 0

# Check SHAP output format
print("SHAP shape:", np.array(shap_values).shape)
print("Classes:", le.classes_)

# Select class to explain
class_idx = 0

# Force plot
shap.initjs()

shap.force_plot(
    explainer.expected_value[class_idx],
    shap_values[idx, :, class_idx],
    x_test_scaled.iloc[idx]
)
# Out:
# SHAP shape: (200, 15, 3)
# Classes: ['High' 'Low' 'Medium']
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
import joblib

# Save trained XGBoost model
joblib.dump(xgb_model, "emission_model.pkl")

# Save fitted scaler
joblib.dump(scaler, "scaler.pkl")

# Save exact feature column order
joblib.dump(list(x_train.columns), "model_columns.pkl")

print("Model, scaler, and column list saved successfully.")
# Out:
# Model, scaler, and column list saved successfully.
